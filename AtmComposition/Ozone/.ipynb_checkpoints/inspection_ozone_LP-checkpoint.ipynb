# %% [markdown]
# # Inspection of dataset collections provided in WP2-ICDR-O3-LP-v2

# %% [markdown]
# ### Setup
# First we import the necessary libraries and set a few parameters based on the Delivery Note information, provided in COPCO-1060

# %%
import xarray as xr 
import matplotlib.pyplot as plt
import os
import cartopy
import numpy as np
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.crs as ccrs
import matplotlib as mpl
import cartopy.feature as cfeature
import matplotlib.ticker as mticker
import datetime
import cdsapi
import zipfile 
import pandas as pd
import requests
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import ipywidgets as widgets
from IPython.display import display


# Delivery settings

manifest_file = 'https://wdc.dlr.de/C3S_312b_Lot2/manifest_C3S_312b_Lot2_O3_MONTHLY_2026-02-27.txt'

# set product parameters in a dictionary. adjust for future versions / additional products
product_parameters = {
    'OSIRIS': {
        'sensor_line'         : 'LP', 
        'satellite'           : 'ODIN',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'OSIRIS', # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',    # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0003',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/12/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/11/2001'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'ACE': {
        'sensor_line'         : 'LP',
        'satellite'           : 'SCISAT',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'ACE', # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',    # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0003',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/12/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/02/2004'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'MLS': {
        'sensor_line'         : 'LP',
        'satellite'           : 'AURA',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'MLS',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0003',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/08/2004'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['ozone_mixing_ratio'],
        'height_variable'     : 'pressure' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'SABER': {
        'sensor_line'         : 'LP',
        'satellite'           : 'TIMED',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'SABER',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0002',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/01/2002'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['ozone_mixing_ratio'],
        'height_variable'     : 'pressure' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'SAGE-III': {
        'sensor_line'         : 'LP',
        'satellite'           : 'ISS',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'SAGE_III',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0002',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/09/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/06/2017'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'OMPS-SASK': {
        'sensor_line'         : 'LP',
        'satellite'           : 'NPP',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'OMPS',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'USASK',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0003',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/02/2012'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'OMPS-UBR': {
        'sensor_line'         : 'LP',
        'satellite'           : 'NPP',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'OMPS',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'UBR',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0002',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/02/2012'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'ANOM_MZM': {
        'sensor_line'         : 'LP',
        'satellite'           : 'MERGED',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'ANOM_MZM',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0010',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/10/1984'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['merged_ozone_anomaly'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'CONC_MZM': {
        'sensor_line'         : 'LP',
        'satellite'           : 'MERGED',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'CONC_MZM',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0010',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/10/1984'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['merged_ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'CONC_LLG': {
        'sensor_line'         : 'LP',
        'satellite'           : 'MERGED',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'CONC_LLG',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0006',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/10/2001'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['merged_ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
}

product = 'OSIRIS'
sensor_line         = product_parameters[product]['sensor_line']
satellite           = product_parameters[product]['satellite']
instrument          = product_parameters[product]['instrument']
algorithm           = product_parameters[product]['algorithm']
version             = product_parameters[product]['version']
delivery_start      = product_parameters[product]['delivery_start']
delivery_end        = product_parameters[product]['delivery_end']
collection_start    = product_parameters[product]['collection_start']
collection_end      = product_parameters[product]['collection_end']
temporal_resolution = product_parameters[product]['temporal_resolution']
parameter_list      = product_parameters[product]['parameter_list']
height_variable     = product_parameters[product]['height_variable']

# options for download
download_full_dataset = True # download full CDR or not
download_delivery     = True # download files for this delivery
# directory where we will store the datasets
work_dir = f'/perm/cxjo/datasets/Ozone/{product}/' 
clean_workdir = False        # set if we should delete all the files in the work dir before we start or not

if not os.path.exists(work_dir):
    print(work_dir)
    os.makedirs(work_dir)

if (clean_workdir):
    os.remove(f'{work_dir}/*') # clean directory before we start working (if desired)

# %% [markdown]
# ### Download manifest file and get list of file URLs to download corresponding to the delivery

# %%
# Download manifest file and get list of file URLs to download corresponding to the delivery
local_manif_fname = os.path.basename(manifest_file)
r = requests.get(manifest_file)
with open(local_manif_fname, 'w') as file:
    file.write(r.text)

# now read the manifest file and print the lines corresponding to the satellite and instrument of interest    
# UNCOMMENT if you need to inpect the pattern of the path of each line in the manifest file

# with open(local_manif_fname,'r') as file:                                                                                                                                                                                                                                             
#     for line in file:
#         if satellite in line and instrument in line and version in line and algorithm in line and sensor_line in line:
#             print(line)

# %% [markdown]
# First we define a function that will read the local copy of the manifest file and identify the lines corresponding to the data we are interested in.
# We provide start and end dates, a frequency and the parameters defined in the beginning of the script that are unique to the dataset we are inspecting.
# It will store the missing files into a list and print that list.
# NOTE: We need to be very careful with the file pattern, as it might change for each collection.
# It will return a list of existing files that will be useful below.
# Then we call that function specifying the delivery dates as start and end dates.

# %%
def check_files_in_manifest(date_start, date_end, temporal_resolution,sensor_line,satellite, instrument, algorithm, version, manifest_file):
    # Create a date range
    date_range = pd.date_range(start=date_start, end=date_end, freq=temporal_resolution) # MS: month start frequency
    
    # Prepare the pattern for file names
    missing_files = []
    existing_files = []
    
    # Read the manifest file (assuming it's a list of filenames)
    with open(manifest_file, 'r') as f:
        manifest_files = set(f.read().splitlines())  # Assuming one filename per line
    
    # Loop through the date range and generate the file pattern for each month
    for date in date_range:
        # Format the date in YYYYMM
        YYYYMM = date.strftime('%Y%m')
        # carefully inspect this file pattern:
        file_pattern = f"http://wdc.dlr.de/C3S_312b_Lot2/O3/{sensor_line}/{satellite}/{instrument}/{algorithm}/{version}/L3_MONTHLY/{YYYYMM[:4]}/{YYYYMM}-C3S-L3_OZONE-O3_PRODUCTS-{instrument}-{satellite}-{algorithm}-MONTHLY-{version}.nc"
        # Check if the file is in the manifest
        if file_pattern not in manifest_files:
            missing_files.append(file_pattern)
        else:
            existing_files.append(file_pattern)
    
    if missing_files:
        nmissing = len(missing_files)
        print(f"Missing files for the following {nmissing} date(s):")
        for file in missing_files:
            print(file)
    else:
        print("All expected dates are present in the manifest file.")
        print('Dates:', existing_files)
        
    return existing_files

        
file_list = check_files_in_manifest(delivery_start, delivery_end, temporal_resolution,sensor_line,satellite, instrument, algorithm, version, local_manif_fname)
# Out:
# Missing files for the following 1 date(s):
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2025/202506-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc

# %% [markdown]
# Then we download the data we need to proceed with the analysis.
# We might wish to download only the ICDR we are inspecting, or the full CDR + ICDRs for this dataset version.

# %%
if download_delivery:
    for file in file_list:
        local_fname = work_dir + os.path.basename(file)
        print(local_fname)
        if os.path.exists(local_fname):
            print(f"Already exists: {local_fname}")
            continue
        print(f"Downloading {file}")
        with requests.get(file, stream=True) as r:
            r.raise_for_status()
            with open(local_fname, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)
                        
if download_full_dataset:
    file_list_full = check_files_in_manifest(collection_start, collection_end, temporal_resolution,sensor_line,satellite, instrument, algorithm, version, local_manif_fname)
    for file in file_list_full:
        local_fname = work_dir + os.path.basename(file)
        print(local_fname)
        if os.path.exists(local_fname):
            print(f"Already exists: {local_fname}")
            continue
        print(f"Downloading {file}")
        with requests.get(file, stream=True) as r:
            r.raise_for_status()
            with open(local_fname, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)
# Out:
# /perm/cxjo/datasets/Ozone/OSIRIS/202402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Missing files for the following 14 date(s):
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200102-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200103-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200104-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200105-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200106-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200107-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200108-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200109-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2001/200110-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2018/201806-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2019/201906-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2020/202006-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2021/202106-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/ODIN/OSIRIS/ALG/v0003/L3_MONTHLY/2025/202506-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200111-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200111-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200112-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200112-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200201-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200201-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200202-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200202-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200203-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200203-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200204-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200204-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200205-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200205-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200206-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200206-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200207-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200207-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200208-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200208-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200209-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200209-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200210-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200210-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200211-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200211-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200212-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200212-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200301-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200301-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200302-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200302-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200303-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200303-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200304-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200304-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200305-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200305-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200306-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200306-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200307-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200307-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200308-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200308-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200309-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200309-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200310-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200310-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200311-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200311-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200312-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200312-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200401-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200401-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200506-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200506-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200512-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200512-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200601-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200601-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200602-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200602-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200603-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200603-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200604-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200604-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200605-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200605-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200606-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200606-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200607-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200607-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200608-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200608-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200609-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200609-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200610-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200610-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200611-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200611-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200612-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200612-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200701-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200701-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200702-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200702-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200703-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200703-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200704-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200704-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200705-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200705-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200706-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200706-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200707-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200707-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200708-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200708-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200709-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200709-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200710-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200710-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200711-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200711-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200712-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200712-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200801-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200801-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200802-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200802-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200803-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200803-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200804-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200804-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200805-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200805-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200806-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200806-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200807-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200807-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200808-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200808-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200809-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200809-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200810-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200810-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200811-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200811-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200812-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200812-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200901-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200901-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200902-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200902-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200903-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200903-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200904-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200904-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200905-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200905-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200906-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200906-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200907-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200907-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200908-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200908-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200909-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200909-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200910-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200910-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200911-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200911-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/200912-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/200912-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201001-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201001-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201002-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201002-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201003-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201003-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201004-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201004-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201005-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201005-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201006-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201006-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201007-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201007-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201008-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201008-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201009-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201009-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201010-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201010-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201011-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201011-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201012-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201012-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201101-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201101-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201102-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201102-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201103-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201103-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201104-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201104-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201105-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201105-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201106-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201106-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201107-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201107-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201108-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201108-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201109-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201109-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201110-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201110-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201111-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201111-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201112-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201112-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201201-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201201-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201202-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201202-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201203-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201203-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201204-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201204-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201205-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201205-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201206-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201206-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201207-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201207-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201208-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201208-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201209-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201209-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201210-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201210-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201211-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201211-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201212-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201212-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201301-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201301-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201302-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201302-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201303-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201303-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201304-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201304-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201305-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201305-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201306-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201306-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201307-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201307-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201308-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201308-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201309-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201309-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201310-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201310-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201311-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201311-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201312-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201312-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201401-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201401-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201506-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201506-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201512-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201512-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201601-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201601-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201602-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201602-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201603-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201603-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201604-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201604-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201605-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201605-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201606-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201606-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201607-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201607-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201608-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201608-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201609-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201609-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201610-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201610-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201611-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201611-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201612-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201612-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201701-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201701-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201702-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201702-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201703-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201703-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201704-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201704-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201705-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201705-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201706-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201706-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201707-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201707-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201708-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201708-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201709-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201709-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201710-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201710-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201711-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201711-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201712-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201712-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201801-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201801-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201802-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# ...
# /perm/cxjo/datasets/Ozone/OSIRIS/201905-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201905-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201907-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201907-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201908-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201908-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201909-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201909-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201910-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201910-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201911-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201911-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/201912-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/201912-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202001-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202001-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202002-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202002-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202003-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202003-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202004-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202004-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202005-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202005-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202007-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202007-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202008-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202008-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202009-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202009-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202010-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202010-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202011-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202011-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202012-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202012-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202101-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202101-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202102-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202102-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202103-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202103-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202104-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202104-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202105-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202105-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202107-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202107-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202108-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202108-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202109-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202109-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202110-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202110-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202111-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202111-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202112-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202112-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202201-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202201-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202202-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202202-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202203-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202203-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202204-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202204-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202205-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202205-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202206-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202206-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202207-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202207-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202208-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202208-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202209-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202209-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202210-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202210-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202211-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202211-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202212-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202212-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202301-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202301-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202302-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202302-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202303-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202303-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202304-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202304-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202305-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202305-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202306-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202306-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202307-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202307-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202308-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202308-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202309-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202309-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202310-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202310-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202311-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202311-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202312-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202312-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202401-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202401-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202402-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202403-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202404-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202405-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202406-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202407-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202408-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202409-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202410-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202411-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202412-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202501-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202502-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202503-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202504-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202505-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202507-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202508-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202509-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202510-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# /perm/cxjo/datasets/Ozone/OSIRIS/202511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# Already exists: /perm/cxjo/datasets/Ozone/OSIRIS/202511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc

# %% [markdown]
# ## Dataset inspection
# ### Check metadata
# Open a random file from the collection and display its contents and attributes (in this case last file in the list)

# %%
fname = work_dir + os.path.basename(file_list[-1]) # last file of the list of existing files, for example.
print(fname)
nc = xr.open_dataset(fname)
print(nc.info())
# Out:
# /perm/cxjo/datasets/Ozone/OSIRIS/202511-C3S-L3_OZONE-O3_PRODUCTS-OSIRIS-ODIN-ALG-MONTHLY-v0003.nc
# xarray.Dataset {
# dimensions:
# 	latitude_centers = 18 ;
# 	altitude = 59 ;
#
# variables:
# 	float32 latitude_centers(latitude_centers) ;
# 		latitude_centers:units = degrees_north ;
# 		latitude_centers:standard_name = latitude ;
# 		latitude_centers:long_name = centers of latitude bins ;
# 	float32 altitude(altitude) ;
# 		altitude:units = km ;
# 		altitude:standard_name = altitude ;
# 		altitude:long_name = geometric altitude ;
# 	float64 ozone_concentration(altitude, latitude_centers) ;
# 		ozone_concentration:units = mol m-3 ;
# 		ozone_concentration:standard_name = mole_concentration_of_ozone_in_air ;
# 		ozone_concentration:long_name = monthly zonal mean ozone concentration ;
# 		ozone_concentration:multiplication_factor_to_convert_to_molecules_percm3 = 6.022140857E+17 ;
# 		ozone_concentration:multiplication_factor_to_convert_to_DU_perkm = 2.24115E+06 ;
# 	float32 standard_error_of_the_mean(altitude, latitude_centers) ;
# 		standard_error_of_the_mean:units = % ;
# 		standard_error_of_the_mean:long_name = uncertainty of the monthly zonal  mean data, std/sqrt(N) ;
# 	float32 sample_standard_deviation(altitude, latitude_centers) ;
# 		sample_standard_deviation:units = % ;
# 		sample_standard_deviation:long_name = Sample standard deviation in 1 month x10 deg bins ;
# 	float32 mean_uncertainty_estimate(altitude, latitude_centers) ;
# 		mean_uncertainty_estimate:units = % ;
# 		mean_uncertainty_estimate:long_name = mean of individual profile error estimates ;
# 	float32 inhomogeneity_in_time(altitude, latitude_centers) ;
# 		inhomogeneity_in_time:units = 1 ;
# 		inhomogeneity_in_time:long_name = inhomogeneity measure in time ;
# 		inhomogeneity_in_time:comment = inhomogeneity measure ranges from 0 (homogeneous) to 1 (highly inhomogeneous), Sofieva et al., 2014, AMT ;
# 	float32 inhomogeneity_in_latitude(altitude, latitude_centers) ;
# 		inhomogeneity_in_latitude:units = 1 ;
# 		inhomogeneity_in_latitude:long_name = inhomogeneity measure in latitude ;
# 		inhomogeneity_in_latitude:comment = inhomogeneity measure ranges from 0 (homogeneous) to 1 (highly inhomogeneous), Sofieva et al., 2014, AMT ;
# 	float32 pressure(altitude, latitude_centers) ;
# 		pressure:units = hPa ;
# 		pressure:standard_name = air_pressure ;
# 		pressure:comment = mean air pressure corresponding to the spatiotemporal bins ;
# 	float32 temperature(altitude, latitude_centers) ;
# 		temperature:units = K ;
# 		temperature:standard_name = air_temperature ;
# 		temperature:comment = mean air temperature corresponding to the spatiotemporal bins ;
#
# // global attributes:
# 	:summary = Monthly zonal mean ozone profiles in 10-deg latitude zones and data uncertainty characterization ;
# 	:sensor = OSIRIS ;
# 	:platform = ODIN ;
# 	:source = OSIRIS Level 2  USask v7.4, HARMOZ_ALT ;
# 	:year = 2025.0 ;
# 	:number_of_altitude_levels = 59 ;
# 	:number_of_latitude_bins = 18 ;
# 	:geospatial_lat_resolution = 10 deg  ;
# 	:geospatial_lat_min = -90 ;
# 	:geospatial_lat_max = 90 ;
# 	:time_coverage_duration = P1M ;
# 	:time_coverage_resolution = P1M ;
# 	:time_coverage_start = 20251101 ;
# 	:time_coverage_end = 20251130 ;
# 	:value_for_nodata = NaN ;
# 	:date_created = 20260224T135030 ;
# 	:creator_name = Viktoria Sofieva ;
# 	:creator_email = viktoria.sofieva@fmi.fi ;
# 	:address = P.O.Box 503, 00101 Helsinki, Finland ;
# 	:naming_authority = FMI - Finnish Meteorological Institute ;
# 	:Conventions = CF-1.5 ;
# 	:standard_name_vocabulary = NetCDF Climate and Forecast(CF) Metadata Convention version 18 ;
# 	:file_version = fv0003 ;
# 	:tracking_id = 47b3ea3a-1eea-4830-aac7-e8bc04259eec ;
# }None

# %% [markdown]
# Now lets produce visualisations of the datasets we are interested in.
# For LP, we have latitude-height cross-sections, so the visualisations here are very specific for this sensor line

# %%
# list of local filenames
flist_local = [work_dir + os.path.basename(file_list[i]) for i in range(len(file_list))]

def preprocess(ds):
    filename = ds.encoding["source"]
    yyyymm = os.path.basename(filename)[:6]
    time = pd.to_datetime(yyyymm, format="%Y%m")
    return ds.expand_dims(time=[time])

ds_all = xr.open_mfdataset(
    flist_local,
    preprocess=preprocess,
    concat_dim="time",
    combine="nested"
)

date_range = pd.date_range(start=delivery_start, end=delivery_end, freq=temporal_resolution) # MS: month start frequency
ds_all = ds_all.reindex(time=date_range)

# Extract arrays
ozone = ds_all[parameter_list[0]].values
lat = ds_all["latitude_centers"].values
alt = ds_all[height_variable].values
times = ds_all["time"].values

# Create figure
fig, ax = plt.subplots(figsize=(8,5))

# Initial frame
im = ax.imshow(
    ozone[0],
    origin="lower",
    aspect="auto",
    extent=[lat.min(), lat.max(), alt.min(), alt.max()],
    cmap="viridis"
)

cbar = plt.colorbar(im, ax=ax)
if "long_name" in ds_all[parameter_list[0]].attrs:
    long_name = ds_all[parameter_list[0]].attrs["long_name"]
else:
    print("long_name attribute not set")
    long_name = ds_all[parameter_list[0]].standard_name  
units = ds_all[parameter_list[0]].units
cbar.set_label(f'{long_name}'+' / '+ f'{units}')

ax.set_xlabel("Latitude")
if "long_name" in ds_all[height_variable].attrs:
    long_name=ds_all[height_variable].attrs["long_name"]
else:
    print("long_name attribute not set")
    long_name = ds_all[height_variable].standard_name  
units = ds_all[height_variable].units

ax.set_ylabel(f'{long_name}'+' / '+ f'{units}')
# invert pressure axis
if height_variable == "pressure":
    ax.invert_yaxis()
title = ax.set_title(str(times[0]))

# Update function
def update(frame):
    im.set_array(ozone[frame])
    title.set_text(f'{product}\n'+np.datetime_as_string(times[frame], unit='M'))
    return im, title

# Create animation
ani = FuncAnimation(
    fig,
    update,
    frames=len(times),
    interval=500,
    blit=False
)

plt.close(fig)

HTML(ani.to_jshtml())

# ds_all["ozone_concentration"].hvplot.quadmesh(
#     x="latitude_centers",
#     y="altitude",
#     groupby="time",
#     cmap="viridis",
#     rasterize=True,
#     frame_width=700,
#     frame_height=400
# )
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4e92d0f1587e4dcba3e0419825bcd4da">
#   <div class="anim-controls">
#     <input id="_anim_slider4e92d0f1587e4dcba3e0419825bcd4da" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4e92d0f1587e4dcba3e0419825bcd4da.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4e92d0f1587e4dcba3e0419825bcd4da.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4e92d0f1587e4dcba3e0419825bcd4da"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4e92d0f1587e4dcba3e0419825bcd4da"
#              >
#       <label for="_anim_radio1_4e92d0f1587e4dcba3e0419825bcd4da">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4e92d0f1587e4dcba3e0419825bcd4da"
#              checked>
#       <label for="_anim_radio2_4e92d0f1587e4dcba3e0419825bcd4da">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4e92d0f1587e4dcba3e0419825bcd4da"
#              >
#       <label for="_anim_radio3_4e92d0f1587e4dcba3e0419825bcd4da">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4e92d0f1587e4dcba3e0419825bcd4da";
#     var slider_id = "_anim_slider4e92d0f1587e4dcba3e0419825bcd4da";
#     var loop_select_id = "_anim_loop_select4e92d0f1587e4dcba3e0419825bcd4da";
#     var frames = new Array(22);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAdqJJR

# %% [markdown]
# ## Examine missing values and ozone distribution

# %%
monthly_data = []

var_name = parameter_list[0]

for i in range(len(ds_all.time)):
    month_values = ds_all[var_name].isel(time=i).values.flatten()
    # keep only valid numbers
    month_values = month_values[~np.isnan(month_values)]
    monthly_data.append(month_values)

months = pd.to_datetime(ds_all.time.values).strftime("%Y-%m")
x_pos = np.arange(len(months))

fig, ax1 = plt.subplots(figsize=(14,6))

# Bar chart: missing fraction
total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]
missing_count = ds_all[var_name].isnull().sum(dim=("latitude_centers", height_variable))
missing_fraction = missing_count / total_cells *100

ax1.bar(x_pos, missing_fraction, color="lightcoral", alpha=0.5, label="Missing fraction")
ax1.set_ylabel("Missing fraction", color="red")
ax1.set_ylim(0, 100)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(months, rotation=90)

# Boxplot: ozone concentration
ax2 = ax1.twinx()
# Only include months with data for the boxplot
valid_data = [d if len(d) > 0 else [np.nan] for d in monthly_data]
ax2.boxplot(valid_data, positions=x_pos, widths=0.3, patch_artist=True,
            boxprops=dict(facecolor="lightblue", color="blue"),
            medianprops=dict(color="darkblue"))

if "long_name" in ds_all[parameter_list[0]].attrs:
    long_name = ds_all[parameter_list[0]].attrs["long_name"]
else:
    print("long_name attribute not set")
    long_name = ds_all[parameter_list[0]].standard_name  
units = ds_all[parameter_list[0]].units

ax2.set_ylabel(f'{long_name}'+' / '+ f'{units}')
ax2.set_xticks(np.arange(len(monthly_data)))
ax2.set_xticklabels(months, rotation=90)

plt.title(f"{product} Ozone concentration per month with missing fraction overlay")
fig.tight_layout()
plt.show()
# Out:
# /etc/ecmwf/ssd/ssd1/tmpdirs/cxjo.3155696.20260313_095421.768/ipykernel_2314305/1362925841.py:17: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]

# %% [markdown]
# ### Now we look into the full timeseries

# %%
flist_local_full = [work_dir + os.path.basename(file_list_full[i]) for i in range(len(file_list_full))]

def preprocess(ds):
    filename = ds.encoding["source"]
    yyyymm = os.path.basename(filename)[:6]
    time = pd.to_datetime(yyyymm, format="%Y%m")
    return ds.expand_dims(time=[time])

ds_all = xr.open_mfdataset(
    flist_local_full,
    preprocess=preprocess,
    concat_dim="time",
    combine="nested"
)

date_range = pd.date_range(start=collection_start, end=collection_end, freq=temporal_resolution) # MS: month start frequency
ds_all = ds_all.reindex(time=date_range)


monthly_data = []

for i in range(len(ds_all.time)):
    month_values = ds_all[var_name].isel(time=i).values.flatten()
    # keep only valid numbers
    month_values = month_values[~np.isnan(month_values)]
    monthly_data.append(month_values)

months = pd.to_datetime(ds_all.time.values).strftime("%Y-%m")
x_pos = np.arange(len(months))

# compute percentiles for all months in timeseries

# Percentiles to compute
pct = [50, 99]

# Store results
percentiles = {p: [] for p in pct}

# Flatten each month and compute percentiles
for i in range(len(ds_all.time)):
    month_values = ds_all[var_name].isel(time=i).values.flatten()
    month_values = month_values[~np.isnan(month_values)]  # ignore NaNs
    if len(month_values) == 0:
        # if month is fully missing, use NaN
        for p in pct:
            percentiles[p].append(np.nan)
    else:
        for p in pct:
            percentiles[p].append(np.percentile(month_values, p))

# Convert to DataFrame for convenience
df_pct = pd.DataFrame(percentiles, index=pd.to_datetime(ds_all.time.values))



# x positions (one per month)
x_pos = np.arange(len(df_pct))

fig, ax1 = plt.subplots(figsize=(14,6))

# -----------------------------
# Bar chart: missing fraction
# -----------------------------
total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]
missing_count = ds_all[var_name].isnull().sum(dim=("latitude_centers", height_variable))
missing_fraction = missing_count / total_cells * 100

ax1.bar(x_pos, missing_fraction, color="lightcoral", alpha=0.5, label="Missing fraction")
ax1.set_ylabel("Missing fraction [%]", color="red")
ax1.set_ylim(0, 100)
ax1.set_xticks(x_pos)
# Reduce X-axis labels: every other year
months = pd.to_datetime(ds_all.time.values)
xticks = months[months.month==1][::2]  # pick Jan every other year
xtick_pos = [x_pos[i] for i in range(len(months)) if months[i] in xticks]
ax1.set_xticks(xtick_pos)
ax1.set_xticklabels([d.year for d in xticks], rotation=45)

# -----------------------------
# Percentiles
# -----------------------------
ax2 = ax1.twinx()
colors = ["blue", "green", "black", "orange", "red"]

ax2.plot(x_pos, df_pct[50], marker="o", linestyle="-", color='blue', label=f"Median")
ax2.plot(x_pos, df_pct[99], marker="s", linestyle="-", color='black', label=f"{99}th percentile")

ax2.set_ylabel(f"{product} Ozone concentration")
ax2.set_title("Monthly ozone percentiles and fraction of missing values")
ax2.legend(loc="upper left")

plt.tight_layout()
plt.show()
# Out:
# /etc/ecmwf/ssd/ssd1/tmpdirs/cxjo.3155696.20260313_095421.768/ipykernel_2314305/3191393645.py:64: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]

# %%
# !jupyter nbconvert --to html inspection_ozone_LP.ipynb
# Out:
# [NbConvertApp] Converting notebook inspection_ozone_LP.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 3 image(s).
# [NbConvertApp] Writing 1563111 bytes to inspection_ozone_LP.html
