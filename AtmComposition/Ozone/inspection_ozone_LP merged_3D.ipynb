# %% [markdown]
# # Inspection of dataset collections provided in WP2-ICDR-O3-LP-v2

# %% [markdown]
# ### Setup
# First we import the necessary libraries and set a few parameters based on the Delivery Note information, provided in COPCO-1060

# %%
import xarray as xr 
import matplotlib.pyplot as plt
import os
import cartopy
import numpy as np
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.crs as ccrs
import matplotlib as mpl
import cartopy.feature as cfeature
import matplotlib.ticker as mticker
import datetime
import cdsapi
import zipfile 
import pandas as pd
import requests
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import ipywidgets as widgets
from IPython.display import display


# Delivery settings

manifest_file = 'https://wdc.dlr.de/C3S_312b_Lot2/manifest_C3S_312b_Lot2_O3_MONTHLY_2026-02-27.txt'

# set product parameters in a dictionary. adjust for future versions / additional products
product_parameters = {
    'CONC_MZM': {
        'sensor_line'         : 'LP',
        'satellite'           : 'MERGED',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'CONC_MZM',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0010',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/10/1984'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['merged_ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
    'CONC_LLG': {
        'sensor_line'         : 'LP',
        'satellite'           : 'MERGED',   # make sure to use the correct satellite name as per the manifest file
        'instrument'          : 'CONC_LLG',    # make sure to use the correct instrument name as per the manifest file
        'algorithm'           : 'ALG',      # trying to make this generic enough. most datasets only have a generic 'ALG'
        'version'             : 'v0006',  # make sure to use the correct version as per the manifest file
        'delivery_start'      : pd.Timestamp('01/11/2024'), # start date of *this* delivery
        'delivery_end'        : pd.Timestamp('30/11/2025'),
        'collection_start'    : pd.Timestamp('01/10/2001'), # start date of the *whole* dataset
        'collection_end'      : pd.Timestamp('30/11/2025'),
        'temporal_resolution' : 'MS', # frequency_code = 'MS' # 'D' for daily, 'MS' for monthly, 'AS' for annual
        'parameter_list'      : ['merged_ozone_concentration'],
        'height_variable'     : 'altitude' # name of the height variable in the dataset. needed for plotting. if not set, will default to 'altitude'
    },
}

product = 'CONC_LLG'
sensor_line         = product_parameters[product]['sensor_line']
satellite           = product_parameters[product]['satellite']
instrument          = product_parameters[product]['instrument']
algorithm           = product_parameters[product]['algorithm']
version             = product_parameters[product]['version']
delivery_start      = product_parameters[product]['delivery_start']
delivery_end        = product_parameters[product]['delivery_end']
collection_start    = product_parameters[product]['collection_start']
collection_end      = product_parameters[product]['collection_end']
temporal_resolution = product_parameters[product]['temporal_resolution']
parameter_list      = product_parameters[product]['parameter_list']
height_variable     = product_parameters[product]['height_variable']

# options for download
download_full_dataset = True # download full CDR or not
download_delivery     = True # download files for this delivery
# directory where we will store the datasets
work_dir = f'/perm/cxjo/datasets/Ozone/{product}/' 
clean_workdir = False        # set if we should delete all the files in the work dir before we start or not

if not os.path.exists(work_dir):
    print(work_dir)
    os.makedirs(work_dir)

if (clean_workdir):
    os.remove(f'{work_dir}/*') # clean directory before we start working (if desired)

# %% [markdown]
# ### Download manifest file and get list of file URLs to download corresponding to the delivery

# %%
# Download manifest file and get list of file URLs to download corresponding to the delivery
local_manif_fname = os.path.basename(manifest_file)
r = requests.get(manifest_file)
with open(local_manif_fname, 'w') as file:
    file.write(r.text)

# now read the manifest file and print the lines corresponding to the satellite and instrument of interest    
# UNCOMMENT if you need to inpect the pattern of the path of each line in the manifest file

# with open(local_manif_fname,'r') as file:                                                                                                                                                                                                                                             
#     for line in file:
#         if satellite in line and instrument in line and version in line and algorithm in line and sensor_line in line:
#             print(line)

# %% [markdown]
# First we define a function that will read the local copy of the manifest file and identify the lines corresponding to the data we are interested in.
# We provide start and end dates, a frequency and the parameters defined in the beginning of the script that are unique to the dataset we are inspecting.
# It will store the missing files into a list and print that list.
# NOTE: We need to be very careful with the file pattern, as it might change for each collection.
# It will return a list of existing files that will be useful below.
# Then we call that function specifying the delivery dates as start and end dates.

# %%
def check_files_in_manifest(date_start, date_end, temporal_resolution,sensor_line,satellite, instrument, algorithm, version, manifest_file):
    # Create a date range
    date_range = pd.date_range(start=date_start, end=date_end, freq=temporal_resolution) # MS: month start frequency
    
    # Prepare the pattern for file names
    missing_files = []
    existing_files = []
    
    # Read the manifest file (assuming it's a list of filenames)
    with open(manifest_file, 'r') as f:
        manifest_files = set(f.read().splitlines())  # Assuming one filename per line
    
    # Loop through the date range and generate the file pattern for each month
    for date in date_range:
        # Format the date in YYYYMM
        YYYYMM = date.strftime('%Y%m')
        # carefully inspect this file pattern:
        file_pattern = f"http://wdc.dlr.de/C3S_312b_Lot2/O3/{sensor_line}/{satellite}/{instrument}/{algorithm}/{version}/L3_MONTHLY/{YYYYMM[:4]}/{YYYYMM}-C3S-L3_OZONE-O3_PRODUCTS-{instrument}-{satellite}-{algorithm}-MONTHLY-{version}.nc"
        # Check if the file is in the manifest
        if file_pattern not in manifest_files:
            missing_files.append(file_pattern)
        else:
            existing_files.append(file_pattern)
    
    if missing_files:
        nmissing = len(missing_files)
        print(f"Missing files for the following {nmissing} date(s):")
        for file in missing_files:
            print(file)
    else:
        print("All expected dates are present in the manifest file.")
        print('Dates:', existing_files)
        
    return existing_files

        
file_list = check_files_in_manifest(delivery_start, delivery_end, temporal_resolution,sensor_line,satellite, instrument, algorithm, version, local_manif_fname)
# Out:
# Missing files for the following 10 date(s):
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202402-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202403-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202404-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202405-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202406-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202407-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202408-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202409-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202410-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202411-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc

# %% [markdown]
# Then we download the data we need to proceed with the analysis.
# We might wish to download only the ICDR we are inspecting, or the full CDR + ICDRs for this dataset version.

# %%
if download_delivery:
    for file in file_list:
        local_fname = work_dir + os.path.basename(file)
        print(local_fname)
        if os.path.exists(local_fname):
            print(f"Already exists: {local_fname}")
            continue
        print(f"Downloading {file}")
        with requests.get(file, stream=True) as r:
            r.raise_for_status()
            with open(local_fname, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)
                        
if download_full_dataset:
    file_list_full = check_files_in_manifest(collection_start, collection_end, temporal_resolution,sensor_line,satellite, instrument, algorithm, version, local_manif_fname)
    for file in file_list_full:
        local_fname = work_dir + os.path.basename(file)
        print(local_fname)
        if os.path.exists(local_fname):
            print(f"Already exists: {local_fname}")
            continue
        print(f"Downloading {file}")
        with requests.get(file, stream=True) as r:
            r.raise_for_status()
            with open(local_fname, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)
# Out:
# /perm/cxjo/datasets/Ozone/CONC_LLG/202412-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202412-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202501-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202501-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202502-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202502-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202503-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202503-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202504-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202504-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202505-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202505-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202506-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202506-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202507-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202507-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202508-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202508-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202509-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202509-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202510-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202510-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202511-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202511-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Missing files for the following 286 date(s):
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200102-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200103-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200104-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200105-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200106-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200107-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200108-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200109-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200110-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200111-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2001/200112-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200201-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200202-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200203-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200204-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200205-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200206-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200207-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200208-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200209-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200210-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200211-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2002/200212-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200301-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200302-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200303-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200304-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200305-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200306-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200307-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200308-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200309-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200310-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200311-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2003/200312-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200401-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200402-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200403-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200404-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200405-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200406-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200407-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200408-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200409-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200410-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200411-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2004/200412-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200501-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200502-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200503-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200504-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200505-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200506-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200507-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200508-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200509-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200510-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200511-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2005/200512-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200601-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200602-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200603-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200604-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200605-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200606-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200607-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200608-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200609-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200610-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200611-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2006/200612-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200701-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200702-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200703-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200704-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200705-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200706-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200707-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200708-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200709-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200710-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200711-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2007/200712-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200801-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200802-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200803-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200804-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200805-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200806-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200807-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200808-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200809-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200810-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200811-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2008/200812-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200901-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200902-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200903-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200904-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200905-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200906-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200907-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200908-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200909-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200910-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200911-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2009/200912-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201001-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201002-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201003-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201004-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201005-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201006-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201007-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201008-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201009-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201010-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201011-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2010/201012-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201101-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201102-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201103-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201104-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201105-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201106-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201107-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201108-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201109-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201110-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201111-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2011/201112-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201201-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201202-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201203-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201204-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201205-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201206-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201207-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201208-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201209-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201210-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201211-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2012/201212-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201301-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201302-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201303-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201304-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201305-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201306-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201307-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201308-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201309-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201310-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201311-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2013/201312-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201401-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201402-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201403-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201404-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201405-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201406-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201407-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201408-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201409-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201410-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201411-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2014/201412-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201501-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201502-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201503-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201504-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201505-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201506-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201507-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201508-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201509-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201510-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201511-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2015/201512-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201601-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201602-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201603-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201604-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201605-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201606-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201607-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201608-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201609-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201610-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201611-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2016/201612-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201701-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201702-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201703-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201704-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201705-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201706-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201707-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201708-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201709-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201710-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201711-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2017/201712-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201801-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201802-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201803-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201804-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201805-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201806-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201807-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201808-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201809-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201810-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201811-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2018/201812-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201901-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201902-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201903-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201904-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201905-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201906-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201907-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201908-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201909-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201910-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201911-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2019/201912-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202001-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202002-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202003-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202004-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202005-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202006-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202007-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202008-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202009-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202010-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202011-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2020/202012-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202101-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202102-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202103-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202104-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202105-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202106-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202107-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202108-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202109-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202110-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202111-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2021/202112-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202201-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202202-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202203-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202204-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202205-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202206-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202207-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202208-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202209-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202210-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202211-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2022/202212-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202301-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202302-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202303-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202304-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202305-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202306-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202307-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202308-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202309-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202310-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202311-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2023/202312-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202401-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202402-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202403-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202404-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202405-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202406-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202407-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202408-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202409-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202410-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# http://wdc.dlr.de/C3S_312b_Lot2/O3/LP/MERGED/CONC_LLG/ALG/v0006/L3_MONTHLY/2024/202411-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202412-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202412-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202501-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202501-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202502-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202502-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202503-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202503-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202504-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202504-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202505-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202505-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202506-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202506-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202507-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202507-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202508-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202508-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202509-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202509-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202510-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202510-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# /perm/cxjo/datasets/Ozone/CONC_LLG/202511-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# Already exists: /perm/cxjo/datasets/Ozone/CONC_LLG/202511-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc

# %% [markdown]
# ## Dataset inspection
# ### Check metadata
# Open a random file from the collection and display its contents and attributes (in this case last file in the list)

# %%
fname = work_dir + os.path.basename(file_list[-1]) # last file of the list of existing files, for example.
print(fname)
nc = xr.open_dataset(fname)
print(nc.info())
# Out:
# /perm/cxjo/datasets/Ozone/CONC_LLG/202511-C3S-L3_OZONE-O3_PRODUCTS-CONC_LLG-MERGED-ALG-MONTHLY-v0006.nc
# xarray.Dataset {
# dimensions:
# 	latitude_centers = 18 ;
# 	longitude_centers = 18 ;
# 	altitude = 41 ;
# 	instruments = 6 ;
#
# variables:
# 	float32 latitude_centers(latitude_centers) ;
# 		latitude_centers:units = degrees_north ;
# 		latitude_centers:standard_name = latitude ;
# 		latitude_centers:long_name = centers of 10 deg latitude bins ;
# 	float32 longitude_centers(longitude_centers) ;
# 		longitude_centers:units = degree_east ;
# 		longitude_centers:standard_name = longitude ;
# 		longitude_centers:long_name = centers of longitude bins ;
# 	float32 altitude(altitude) ;
# 		altitude:units = km ;
# 		altitude:standard_name = altitude ;
# 	int16 instruments(instruments) ;
# 		instruments:units = 1 ;
# 		instruments:long_name = index of instruments: 1-GOMOS, 2-MIPAS, 3-SCIAMACHY, 4-OSIRIS, 5-MLS, 6- OMPS-LP ;
# 	float64 merged_ozone_concentration(longitude_centers, latitude_centers, altitude) ;
# 		merged_ozone_concentration:units = mol m-3 ;
# 		merged_ozone_concentration:standard_name = mole_concentration_of_ozone_in_air ;
# 		merged_ozone_concentration:long_name = merged monthly zonal mean ozone concentration ;
# 		merged_ozone_concentration:multiplication_factor_to_convert_to_molecules_percm3 = 6.022140857E+17 ;
# 		merged_ozone_concentration:multiplication_factor_to_convert_to_DU_perkm = 2.24115E+06 ;
# 	float64 uncertainty_of_merged_ozone_concentration(longitude_centers, latitude_centers, altitude) ;
# 		uncertainty_of_merged_ozone_concentration:units = mol m-3 ;
# 		uncertainty_of_merged_ozone_concentration:long_name = unertainty of merged monthly zonal mean ozone concentration ;
# 		uncertainty_of_merged_ozone_concentration:multiplication_factor_to_convert_to_molecules_percm3 = 6.022140857E+17 ;
# 		uncertainty_of_merged_ozone_concentration:multiplication_factor_to_convert_to_DU_perkm = 2.24115E+06 ;
# 	float64 ozone_concentration_instrument(instruments, longitude_centers, latitude_centers, altitude) ;
# 		ozone_concentration_instrument:units = mol m-3 ;
# 		ozone_concentration_instrument:standard_name = mole_concentration_of_ozone_in_air ;
# 		ozone_concentration_instrument:long_name = ozone concentration from individual instruments ;
# 		ozone_concentration_instrument:multiplication_factor_to_convert_to_molecules_percm3 = 6.022140857E+17 ;
# 		ozone_concentration_instrument:multiplication_factor_to_convert_to_DU_perkm = 2.24115E+06 ;
# 	float64 uncertainty_of_ozone_concentration_instrument(instruments, longitude_centers, latitude_centers, altitude) ;
# 		uncertainty_of_ozone_concentration_instrument:units = % ;
# 		uncertainty_of_ozone_concentration_instrument:long_name = uncertainties of ozone concentration from individual instruments ;
# 	float32 temperature(longitude_centers, latitude_centers, altitude) ;
# 		temperature:units = K ;
# 		temperature:standard_name = air_temperature ;
# 		temperature:comment = mean air temperature corresponding to the spatiotemporal bins ;
# 	float32 pressure(longitude_centers, latitude_centers, altitude) ;
# 		pressure:units = hPa ;
# 		pressure:standard_name = air_pressure ;
# 		pressure:comment = mean air pressure corresponding to the spatiotemporal bins ;
#
# // global attributes:
# 	:title = MErged GRIdded Dataset of Ozone Profiles (MEGRIDOP) ;
# 	:summary = merged monthly ozone profiles in 10 x20 deg lat xlon bins,  from Nov 2001 to Dec 2024 ;
# 	:comment = The  detalis of the MEGRIDOP dataset can be found in (Sofieva et al., 2021, ACP) ;
# 	:source = Level 2 ozone profiles from  OSIRIS USask v7.4, GOMOS ALGOM2s v1.0, MIPAS KIT v8, SCIAMACHY UBr v3.5, MLS v5, and OMPS-LP USask 2-D v2.1.0 ;
# 	:number_of_altitude_levels = 41 ;
# 	:number_of_latitude_bins = 18 ;
# 	:number_of_longitude_bins = 18 ;
# 	:geospatial_lat_resolution = 10 deg  ;
# 	:geospatial_lat_min = -90 deg ;
# 	:geospatial_lat_max = 90 deg ;
# 	:geospatial_lon_min = -180 deg ;
# 	:geospatial_lon_max = 180 deg ;
# 	:geospatial_vertical_min = 10 km ;
# 	:geospatial_vertical_max = 50 km ;
# 	:value_for_nodata = NaN ;
# 	:date_created = 20260225T173912 ;
# 	:institution = Finnish Meteorological Institute ;
# 	:creator_name = Viktoria Sofieva ;
# 	:creator_email = viktoria.sofieva@fmi.fi ;
# 	:address = P.O.Box 503, 00101 Helsinki, Finland ;
# 	:Conventions = CF-1.6 ;
# 	:standard_name_vocabulary = NetCDF Climate and Forecast(CF) Metadata Convention version 18 ;
# 	:time_coverage_duration = P1M ;
# 	:time_coverage_resolution = P1M ;
# 	:time_coverage_start = 20251101 ;
# 	:time_coverage_end = 20251130 ;
# }None

# %% [markdown]
# Now lets produce visualisations of the datasets we are interested in.
# For LP, we have latitude-height cross-sections, so the visualisations here are very specific for this sensor line

# %%
# list of local filenames
flist_local = [work_dir + os.path.basename(file_list[i]) for i in range(len(file_list))]

def preprocess(ds):
    filename = ds.encoding["source"]
    yyyymm = os.path.basename(filename)[:6]
    time = pd.to_datetime(yyyymm, format="%Y%m")
    return ds.expand_dims(time=[time])

ds_all = xr.open_mfdataset(
    flist_local,
    preprocess=preprocess,
    concat_dim="time",
    combine="nested"
)

date_range = pd.date_range(start=delivery_start, end=delivery_end, freq=temporal_resolution) # MS: month start frequency
ds_all = ds_all.reindex(time=date_range)

# Extract arrays
ozone = ds_all[parameter_list[0]].values
lat = ds_all["latitude_centers"].values
alt = ds_all[height_variable].values
times = ds_all["time"].values

# Create figure
fig, ax = plt.subplots(figsize=(8,5))

# Initial frame
im = ax.imshow(
    ozone[0],
    origin="lower",
    aspect="auto",
    extent=[lat.min(), lat.max(), alt.min(), alt.max()],
    cmap="viridis"
)

cbar = plt.colorbar(im, ax=ax)
if "long_name" in ds_all[parameter_list[0]].attrs:
    long_name = ds_all[parameter_list[0]].attrs["long_name"]
else:
    print("long_name attribute not set")
    long_name = ds_all[parameter_list[0]].standard_name  
units = ds_all[parameter_list[0]].units
cbar.set_label(f'{long_name}'+' / '+ f'{units}')

ax.set_xlabel("Latitude")
if "long_name" in ds_all[height_variable].attrs:
    long_name=ds_all[height_variable].attrs["long_name"]
else:
    print("long_name attribute not set")
    long_name = ds_all[height_variable].standard_name  
units = ds_all[height_variable].units

ax.set_ylabel(f'{long_name}'+' / '+ f'{units}')
# invert pressure axis
if height_variable == "pressure":
    ax.invert_yaxis()
title = ax.set_title(str(times[0]))

# Update function
def update(frame):
    im.set_array(ozone[frame])
    title.set_text(f'{product}\n'+np.datetime_as_string(times[frame], unit='M'))
    return im, title

# Create animation
ani = FuncAnimation(
    fig,
    update,
    frames=len(times),
    interval=500,
    blit=False
)

plt.close(fig)

HTML(ani.to_jshtml())

# ds_all["ozone_concentration"].hvplot.quadmesh(
#     x="latitude_centers",
#     y="altitude",
#     groupby="time",
#     cmap="viridis",
#     rasterize=True,
#     frame_width=700,
#     frame_height=400
# )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 30
#      27 fig, ax = plt.subplots(figsize=(8,5))
#      29 # Initial frame
# ---> 30 im = ax.imshow(
#      31     ozone[0],
#      32     origin="lower",
#      33     aspect="auto",
#      34     extent=[lat.min(), lat.max(), alt.min(), alt.max()],
#      35     cmap="viridis"
#      36 )
#      38 cbar = plt.colorbar(im, ax=ax)
#      39 if "long_name" in ds_all[parameter_list[0]].attrs:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/axes/_axes.py:5945, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5942 if aspect is not None:
#    5943     self.set_aspect(aspect)
# -> 5945 im.set_data(X)
#    5946 im.set_alpha(alpha)
#    5947 if im.get_clip_path() is None:
#    5948     # image does not already have clipping set, clip to Axes patch
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/image.py:675, in _ImageBase.set_data(self, A)
#     673 if isinstance(A, PIL.Image.Image):
#     674     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 675 self._A = self._normalize_image_array(A)
#     676 self._imcache = None
#     677 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/image.py:643, in _ImageBase._normalize_image_array(A)
#     641     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     642 if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 643     raise TypeError(f"Invalid shape {A.shape} for image data")
#     644 if A.ndim == 3:
#     645     # If the input data has values outside the valid range (after
#     646     # normalisation), we issue a warning and then clip X to the bounds
#     647     # - otherwise casting wraps extreme values, hiding outliers and
#     648     # making reliable interpretation impossible.
#     649     high = 255 if np.issubdtype(A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (18, 18, 41) for image data

# %% [markdown]
# ## Examine missing values and ozone distribution

# %%
monthly_data = []

var_name = parameter_list[0]

for i in range(len(ds_all.time)):
    month_values = ds_all[var_name].isel(time=i).values.flatten()
    # keep only valid numbers
    month_values = month_values[~np.isnan(month_values)]
    monthly_data.append(month_values)

months = pd.to_datetime(ds_all.time.values).strftime("%Y-%m")
x_pos = np.arange(len(months))

fig, ax1 = plt.subplots(figsize=(14,6))

# Bar chart: missing fraction
total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]
missing_count = ds_all[var_name].isnull().sum(dim=("latitude_centers", height_variable))
missing_fraction = missing_count / total_cells *100

ax1.bar(x_pos, missing_fraction, color="lightcoral", alpha=0.5, label="Missing fraction")
ax1.set_ylabel("Missing fraction", color="red")
ax1.set_ylim(0, 100)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(months, rotation=90)

# Boxplot: ozone concentration
ax2 = ax1.twinx()
# Only include months with data for the boxplot
valid_data = [d if len(d) > 0 else [np.nan] for d in monthly_data]
ax2.boxplot(valid_data, positions=x_pos, widths=0.3, patch_artist=True,
            boxprops=dict(facecolor="lightblue", color="blue"),
            medianprops=dict(color="darkblue"))

if "long_name" in ds_all[parameter_list[0]].attrs:
    long_name = ds_all[parameter_list[0]].attrs["long_name"]
else:
    print("long_name attribute not set")
    long_name = ds_all[parameter_list[0]].standard_name  
units = ds_all[parameter_list[0]].units

ax2.set_ylabel(f'{long_name}'+' / '+ f'{units}')
ax2.set_xticks(np.arange(len(monthly_data)))
ax2.set_xticklabels(months, rotation=90)

plt.title(f"{product} Ozone concentration per month with missing fraction overlay")
fig.tight_layout()
plt.show()
# Out:
# /etc/ecmwf/ssd/ssd1/tmpdirs/cxjo.3155696.20260313_095421.768/ipykernel_3175497/1362925841.py:17: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]

# %% [markdown]
# ### Now we look into the full timeseries

# %%
flist_local_full = [work_dir + os.path.basename(file_list_full[i]) for i in range(len(file_list_full))]

def preprocess(ds):
    filename = ds.encoding["source"]
    yyyymm = os.path.basename(filename)[:6]
    time = pd.to_datetime(yyyymm, format="%Y%m")
    return ds.expand_dims(time=[time])

ds_all = xr.open_mfdataset(
    flist_local_full,
    preprocess=preprocess,
    concat_dim="time",
    combine="nested"
)

date_range = pd.date_range(start=collection_start, end=collection_end, freq=temporal_resolution) # MS: month start frequency
ds_all = ds_all.reindex(time=date_range)


monthly_data = []

for i in range(len(ds_all.time)):
    month_values = ds_all[var_name].isel(time=i).values.flatten()
    # keep only valid numbers
    month_values = month_values[~np.isnan(month_values)]
    monthly_data.append(month_values)

months = pd.to_datetime(ds_all.time.values).strftime("%Y-%m")
x_pos = np.arange(len(months))

# compute percentiles for all months in timeseries

# Percentiles to compute
pct = [50, 99]

# Store results
percentiles = {p: [] for p in pct}

# Flatten each month and compute percentiles
for i in range(len(ds_all.time)):
    month_values = ds_all[var_name].isel(time=i).values.flatten()
    month_values = month_values[~np.isnan(month_values)]  # ignore NaNs
    if len(month_values) == 0:
        # if month is fully missing, use NaN
        for p in pct:
            percentiles[p].append(np.nan)
    else:
        for p in pct:
            percentiles[p].append(np.percentile(month_values, p))

# Convert to DataFrame for convenience
df_pct = pd.DataFrame(percentiles, index=pd.to_datetime(ds_all.time.values))



# x positions (one per month)
x_pos = np.arange(len(df_pct))

fig, ax1 = plt.subplots(figsize=(14,6))

# -----------------------------
# Bar chart: missing fraction
# -----------------------------
total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]
missing_count = ds_all[var_name].isnull().sum(dim=("latitude_centers", height_variable))
missing_fraction = missing_count / total_cells * 100

ax1.bar(x_pos, missing_fraction, color="lightcoral", alpha=0.5, label="Missing fraction")
ax1.set_ylabel("Missing fraction [%]", color="red")
ax1.set_ylim(0, 100)
ax1.set_xticks(x_pos)
# Reduce X-axis labels: every other year
months = pd.to_datetime(ds_all.time.values)
xticks = months[months.month==1][::2]  # pick Jan every other year
xtick_pos = [x_pos[i] for i in range(len(months)) if months[i] in xticks]
ax1.set_xticks(xtick_pos)
ax1.set_xticklabels([d.year for d in xticks], rotation=45)

# -----------------------------
# Percentiles
# -----------------------------
ax2 = ax1.twinx()
colors = ["blue", "green", "black", "orange", "red"]

ax2.plot(x_pos, df_pct[50], marker="o", linestyle="-", color='blue', label=f"Median")
ax2.plot(x_pos, df_pct[99], marker="s", linestyle="-", color='black', label=f"{99}th percentile")

ax2.set_ylabel(f"{product} Ozone concentration")
ax2.set_title("Monthly ozone percentiles and fraction of missing values")
ax2.legend(loc="upper left")

plt.tight_layout()
plt.show()
# Out:
# /etc/ecmwf/ssd/ssd1/tmpdirs/cxjo.3155696.20260313_095421.768/ipykernel_3175497/3191393645.py:64: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   total_cells = ds_all.dims["latitude_centers"] * ds_all.dims[height_variable]

# %%
import ipywidgets as widgets
from IPython.display import display

var = parameter_list[0]

lat = ds_all["latitude_centers"].values
lon = ds_all["longitude_centers"].values
alt = ds_all[height_variable].values
times = ds_all["time"].values

data = ds_all[var]

slice_type = widgets.Dropdown(
    options=["lat-alt", "lon-alt", "lat-lon"],
    value="lat-alt",
    description="Slice:"
)

time_slider = widgets.IntSlider(
    min=0, max=len(times)-1, step=1, value=0,
    description="Time"
)

index_slider = widgets.IntSlider(
    min=0, max=len(lon)-1, step=1, value=0,
    description="Index"
)

fig, ax = plt.subplots(figsize=(8,5))
im = None
cbar = None

def update(*args):
    global im, cbar
    ax.clear()

    t = time_slider.value
    i = index_slider.value
    mode = slice_type.value

    if mode == "lat-alt":
        field = data.isel(time=t, longitude_centers=i)
        extent = [lat.min(), lat.max(), alt.min(), alt.max()]
        xlabel = "Latitude"
        ylabel = height_variable
        ax.set_title(f"{product}\nlon={lon[i]:.2f}")

    elif mode == "lon-alt":
        field = data.isel(time=t, latitude_centers=i)
        extent = [lon.min(), lon.max(), alt.min(), alt.max()]
        xlabel = "Longitude"
        ylabel = height_variable
        ax.set_title(f"{product}\nlat={lat[i]:.2f}")

    elif mode == "lat-lon":
        field = data.isel(time=t, **{height_variable: i})
        extent = [lat.min(), lat.max(), lon.min(), lon.max()]
        xlabel = "Latitude"
        ylabel = "Longitude"
        ax.set_title(f"{product}\n{height_variable}={alt[i]:.2f}")

    im = ax.imshow(
        field.values,
        origin="lower",
        aspect="auto",
        extent=extent,
        cmap="viridis"
    )

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

    if mode != "lat-lon" and height_variable == "pressure":
        ax.invert_yaxis()

    ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))

    if cbar:
        cbar.remove()
    cbar = plt.colorbar(im, ax=ax)

    fig.canvas.draw_idle()

slice_type.observe(update)
time_slider.observe(update)
index_slider.observe(update)

update()

display(slice_type, time_slider, index_slider)
# Out:
# Dropdown(description='Slice:', options=('lat-alt', 'lon-alt', 'lat-lon'), value='lat-alt')
# IntSlider(value=0, description='Time', max=21)
# IntSlider(value=0, description='Index', max=17)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1057, in Colorbar.remove(self)
#    1055     ax._set_position(pos)
#    1056 else:  # use_gridspec was True
# -> 1057     ax.set_subplotspec(subplotspec)
#
# AttributeError: 'NoneType' object has no attribute 'set_subplotspec'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
# ...
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:719, in Widget._lock_property(self, **properties)
#     710 @contextmanager
#     711 def _lock_property(self, **properties):
#     712     """Lock a property-value pair.
#     713
#     714     The value should be the JSON state of the property.
#    (...)
#     717     flawed.  In the future we may want to look into buffering state changes
#     718     back to the front-end."""
# --> 719     self._property_lock = properties
#     720     try:
#     721         yield
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# Cell In[140], line 79, in update(*args)
#      76 ax.set_title(ax.get_title() + "\n" + np.datetime_as_string(times[t], unit="M"))
#      78 if cbar:
# ---> 79     cbar.remove()
#      80 cbar = plt.colorbar(im, ax=ax)
#      82 fig.canvas.draw_idle()
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/colorbar.py:1038, in Colorbar.remove(self)
#    1035         if self.ax in a._colorbars:
#    1036             a._colorbars.remove(self.ax)
# -> 1038 self.ax.remove()
#    1040 self.mappable.callbacks.disconnect(self.mappable.colorbar_cid)
#    1041 self.mappable.colorbar = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/artist.py:239, in Artist.remove(self)
#     234 # There is no method to set the callback.  Instead, the parent should
#     235 # set the _remove_method attribute directly.  This would be a
#     236 # protected attribute if Python supported that sort of thing.  The
#     237 # callback has one parameter, which is the child to be removed.
#     238 if self._remove_method is not None:
# --> 239     self._remove_method(self)
#     240     # clear stale callback
#     241     self.stale_callback = None
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:927, in FigureBase.delaxes(self, ax)
#     923 def delaxes(self, ax):
#     924     """
#     925     Remove the `~.axes.Axes` *ax* from the figure; update the current Axes.
#     926     """
# --> 927     self._remove_axes(ax, owners=[self._axstack, self._localaxes])
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:942, in FigureBase._remove_axes(self, ax, owners)
#     930 """
#     931 Common helper for removal of standard Axes (via delaxes) and of child Axes.
#     932
#    (...)
#     939     will be remove()d.
#     940 """
#     941 for owner in owners:
# --> 942     owner.remove(ax)
#     944 self._axobservers.process("_axes_change_event", self)
#     945 self.stale = True
#
# File /etc/ecmwf/nfs/dh1_perm_a/cxjo/conda/envs/work/lib/python3.12/site-packages/matplotlib/figure.py:89, in _AxesStack.remove(self, a)
#      87 def remove(self, a):
#      88     """Remove the Axes from the stack."""
# ---> 89     self._axes.pop(a)
#
# KeyError: <Axes: label='<colorbar>'>
